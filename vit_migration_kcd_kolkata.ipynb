# %% [markdown]
# <a href="https://colab.research.google.com/github/TithiB-del/Collaboratory-notebooks/blob/main/vit_migration_kcd_kolkata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install namex
# !apt install python3.10-venv
# !git clone https://github.com/keras-team/keras-core.git && cd keras-core && python pip_build.py --install
# !pip install git+https://github.com/soumik12345/wandb-addons
# Out:
# Collecting namex
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Installing collected packages: namex
# Successfully installed namex-0.0.7
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   python3-pip-whl python3-setuptools-whl
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 16 not upgraded.
# Need to get 2,473 kB of archives.
# After this operation, 2,882 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.3 [1,679 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-setuptools-whl all 59.6.0-1.2ubuntu0.22.04.1 [788 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.2 [5,724 B]
# Fetched 2,473 kB in 1s (2,973 kB/s)
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.3_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.3) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.2_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.2) ...
# Setting up python3-setuptools-whl (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.3) ...
# Setting up python3.10-venv (3.10.12-1~22.04.2) ...
# Cloning into 'keras-core'...
# remote: Enumerating objects: 11015, done.
# remote: Counting objects: 100% (2186/2186), done.
# remote: Compressing objects: 100% (621/621), done.
# remote: Total 11015 (delta 1783), reused 1810 (delta 1564), pack-reused 8829
# Receiving objects: 100% (11015/11015), 3.49 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (8475/8475), done.
# ...processing keras_core/src/api_export.py
# ...processing keras_core/src/__init__.py
# ...processing keras_core/src/version.py
# ...processing keras_core/src/mixed_precision/__init__.py
# ...processing keras_core/src/mixed_precision/dtype_policy.py
# ...processing keras_core/src/optimizers/adagrad.py
# ...processing keras_core/src/optimizers/adafactor.py
# ...processing keras_core/src/optimizers/adamw.py
# ...processing keras_core/src/optimizers/optimizer.py
# ...processing keras_core/src/optimizers/nadam.py
# ...processing keras_core/src/optimizers/adamax.py
# ...processing keras_core/src/optimizers/__init__.py
# ...processing keras_core/src/optimizers/base_optimizer.py
# ...processing keras_core/src/optimizers/sgd.py
# ...processing keras_core/src/optimizers/lion.py
# ...processing keras_core/src/optimizers/ftrl.py
# ...processing keras_core/src/optimizers/rmsprop.py
# ...processing keras_core/src/optimizers/adam.py
# ...processing keras_core/src/optimizers/adadelta.py
# ...processing keras_core/src/optimizers/schedules/learning_rate_schedule.py
# ...processing keras_core/src/optimizers/schedules/__init__.py
# ...processing keras_core/src/regularizers/__init__.py
# ...processing keras_core/src/regularizers/regularizers.py
# ...processing keras_core/src/ops/image.py
# ...processing keras_core/src/ops/math.py
# ...processing keras_core/src/ops/core.py
# ...processing keras_core/src/ops/operation.py
# ...processing keras_core/src/ops/operation_utils.py
# ...processing keras_core/src/ops/function.py
# ...processing keras_core/src/ops/__init__.py
# ...processing keras_core/src/ops/numpy.py
# ...processing keras_core/src/ops/symbolic_arguments.py
# ...processing keras_core/src/ops/nn.py
# ...processing keras_core/src/ops/node.py
# ...processing keras_core/src/constraints/__init__.py
# ...processing keras_core/src/constraints/constraints.py
# ...processing keras_core/src/applications/nasnet.py
# ...processing keras_core/src/applications/densenet.py
# ...processing keras_core/src/applications/inception_v3.py
# ...processing keras_core/src/applications/__init__.py
# ...processing keras_core/src/applications/mobilenet_v3.py
# ...processing keras_core/src/applications/vgg19.py
# ...processing keras_core/src/applications/vgg16.py
# ...processing keras_core/src/applications/inception_resnet_v2.py
# ...processing keras_core/src/applications/resnet_v2.py
# ...processing keras_core/src/applications/mobilenet_v2.py
# ...processing keras_core/src/applications/efficientnet.py
# ...processing keras_core/src/applications/resnet.py
# ...processing keras_core/src/applications/efficientnet_v2.py
# ...processing keras_core/src/applications/mobilenet.py
# ...processing keras_core/src/applications/xception.py
# ...processing keras_core/src/applications/convnext.py
# ...processing keras_core/src/applications/imagenet_utils.py
# ...processing keras_core/src/initializers/__init__.py
# ...processing keras_core/src/initializers/constant_initializers.py
# ...processing keras_core/src/initializers/initializer.py
# ...processing keras_core/src/initializers/random_initializers.py
# ...processing keras_core/src/legacy/backend.py
# ...processing keras_core/src/legacy/losses.py
# ...processing keras_core/src/legacy/__init__.py
# ...processing keras_core/src/legacy/layers.py
# ...processing keras_core/src/legacy/saving/serialization.py
# ...processing keras_core/src/legacy/saving/__init__.py
# ...processing keras_core/src/legacy/saving/json_utils.py
# ...processing keras_core/src/legacy/saving/saving_options.py
# ...processing keras_core/src/legacy/saving/legacy_h5_format.py
# ...processing keras_core/src/legacy/saving/saving_utils.py
# ...processing keras_core/src/legacy/preprocessing/image.py
# ...processing keras_core/src/legacy/preprocessing/__init__.py
# ...processing keras_core/src/legacy/preprocessing/text.py
# ...processing keras_core/src/legacy/preprocessing/sequence.py
# ...processing keras_core/src/trainers/__init__.py
# ...processing keras_core/src/trainers/epoch_iterator.py
# ...processing keras_core/src/trainers/trainer.py
# ...processing keras_core/src/trainers/compile_utils.py
# ...processing keras_core/src/trainers/data_adapters/__init__.py
# ...processing keras_core/src/trainers/data_adapters/data_adapter.py
# ...processing keras_core/src/trainers/data_adapters/data_adapter_utils.py
# ...processing keras_core/src/trainers/data_adapters/array_data_adapter.py
# ...processing keras_core/src/trainers/data_adapters/torch_data_adapter.py
# ...processing keras_core/src/trainers/data_adapters/generator_data_adapter.py
# ...processing keras_core/src/trainers/data_adapters/tf_dataset_adapter.py
# ...processing keras_core/src/trainers/data_adapters/py_dataset_adapter.py
# ...processing keras_core/src/distribution/distribution_lib.py
# ...processing keras_core/src/testing/__init__.py
# ...processing keras_core/src/testing/test_case.py
# ...processing keras_core/src/testing/test_utils.py
# ...processing keras_core/src/layers/__init__.py
# ...processing keras_core/src/layers/layer.py
# ...processing keras_core/src/layers/input_spec.py
# ...processing keras_core/src/layers/pooling/average_pooling3d.py
# ...processing keras_core/src/layers/pooling/global_average_pooling1d.py
# ...processing keras_core/src/layers/pooling/global_average_pooling3d.py
# ...processing keras_core/src/layers/pooling/base_global_pooling.py
# ...processing keras_core/src/layers/pooling/__init__.py
# ...processing keras_core/src/layers/pooling/average_pooling2d.py
# ...processing keras_core/src/layers/pooling/global_max_pooling2d.py
# ...processing keras_core/src/layers/pooling/max_pooling3d.py
# ...processing keras_core/src/layers/pooling/max_pooling1d.py
# ...processing keras_core/src/layers/pooling/global_average_pooling2d.py
# ...processing keras_core/src/layers/pooling/global_max_pooling3d.py
# ...processing keras_core/src/layers/pooling/max_pooling2d.py
# ...processing keras_core/src/layers/pooling/average_pooling1d.py
# ...processing keras_core/src/layers/pooling/base_pooling.py
# ...processing keras_core/src/layers/pooling/global_max_pooling1d.py
# ...processing keras_core/src/layers/attention/multi_head_attention.py
# ...processing keras_core/src/layers/attention/additive_attention.py
# ...processing keras_core/src/layers/attention/__init__.py
# ...processing keras_core/src/layers/attention/attention.py
# ...processing keras_core/src/layers/core/embedding.py
# ...processing keras_core/src/layers/core/input_layer.py
# ...processing keras_core/src/layers/core/__init__.py
# ...processing keras_core/src/layers/core/wrapper.py
# ...processing keras_core/src/layers/core/lambda_layer.py
# ...processing keras_core/src/layers/core/einsum_dense.py
# ...processing keras_core/src/layers/core/identity.py
# ...processing keras_core/src/layers/core/masking.py
# ...processing keras_core/src/layers/core/dense.py
# ...processing keras_core/src/layers/normalization/group_normalization.py
# ...processing keras_core/src/layers/normalization/spectral_normalization.py
# ...processing keras_core/src/layers/normalization/unit_normalization.py
# ...processing keras_core/src/layers/normalization/batch_normalization.py
# ...processing keras_core/src/layers/normalization/__init__.py
# ...processing keras_core/src/layers/normalization/layer_normalization.py
# ...processing keras_core/src/layers/rnn/conv_lstm2d.py
# ...processing keras_core/src/layers/rnn/bidirectional.py
# ...processing keras_core/src/layers/rnn/conv_lstm.py
# ...processing keras_core/src/layers/rnn/lstm.py
# ...processing keras_core/src/layers/rnn/conv_lstm1d.py
# ...processing keras_core/src/layers/rnn/rnn.py
# ...processing keras_core/src/layers/rnn/simple_rnn.py
# ...processing keras_core/src/layers/rnn/__init__.py
# ...processing keras_core/src/layers/rnn/gru.py
# ...processing keras_core/src/layers/rnn/dropout_rnn_cell.py
# ...processing keras_core/src/layers/rnn/time_distributed.py
# ...processing keras_core/src/layers/rnn/stacked_rnn_cells.py
# ...processing keras_core/src/layers/rnn/conv_lstm3d.py
# ...processing keras_core/src/layers/merging/concatenate.py
# ...processing keras_core/src/layers/merging/maximum.py
# ...processing keras_core/src/layers/merging/base_merge.py
# ...processing keras_core/src/layers/merging/__init__.py
# ...processing keras_core/src/layers/merging/minimum.py
# ...processing keras_core/src/layers/merging/multiply.py
# ...processing keras_core/src/layers/merging/add.py
# ...processing keras_core/src/layers/merging/average.py
# ...processing keras_core/src/layers/merging/subtract.py
# ...processing keras_core/src/layers/merging/dot.py
# ...processing keras_core/src/layers/activations/elu.py
# ...processing keras_core/src/layers/activations/prelu.py
# ...processing keras_core/src/layers/activations/leaky_relu.py
# ...processing keras_core/src/layers/activations/softmax.py
# ...processing keras_core/src/layers/activations/__init__.py
# ...processing keras_core/src/layers/activations/activation.py
# ...processing keras_core/src/layers/activations/relu.py
# ...processing keras_core/src/layers/convolutional/conv1d.py
# ...processing keras_core/src/layers/convolutional/separable_conv2d.py
# ...processing keras_core/src/layers/convolutional/conv1d_transpose.py
# ...processing keras_core/src/layers/convolutional/conv2d.py
# ...processing keras_core/src/layers/convolutional/conv3d.py
# ...processing keras_core/src/layers/convolutional/__init__.py
# ...processing keras_core/src/layers/convolutional/base_depthwise_conv.py
# ...processing keras_core/src/layers/convolutional/depthwise_conv1d.py
# ...processing keras_core/src/layers/convolutional/base_conv_transpose.py
# ...processing keras_core/src/layers/convolutional/depthwise_conv2d.py
# ...processing keras_core/src/layers/convolutional/base_conv.py
# ...processing keras_core/src/layers/convolutional/conv3d_transpose.py
# ...processing keras_core/src/layers/convolutional/conv2d_transpose.py
# ...processing keras_core/src/layers/convolutional/separable_conv1d.py
# ...processing keras_core/src/layers/convolutional/base_separable_conv.py
# ...processing keras_core/src/layers/preprocessing/feature_space.py
# ...processing keras_core/src/layers/preprocessing/random_translation.py
# ...processing keras_core/src/layers/preprocessing/random_rotation.py
# ...processing keras_core/src/layers/preprocessing/hashed_crossing.py
# ...processing keras_core/src/layers/preprocessing/discretization.py
# ...processing keras_core/src/layers/preprocessing/rescaling.py
# ...processing keras_core/src/layers/preprocessing/hashing.py
# ...processing keras_core/src/layers/preprocessing/string_lookup.py
# ...processing keras_core/src/layers/preprocessing/__init__.py
# ...processing keras_core/src/layers/preprocessing/random_contrast.py
# ...processing keras_core/src/layers/preprocessing/index_lookup.py
# ...processing keras_core/src/layers/preprocessing/random_flip.py
# ...processing keras_core/src/layers/preprocessing/random_zoom.py
# ...processing keras_core/src/layers/preprocessing/random_brightness.py
# ...processing keras_core/src/layers/preprocessing/normalization.py
# ...processing keras_core/src/layers/preprocessing/integer_lookup.py
# ...processing keras_core/src/layers/preprocessing/random_crop.py
# ...processing keras_core/src/layers/preprocessing/text_vectorization.py
# ...processing keras_core/src/layers/preprocessing/resizing.py
# ...processing keras_core/src/layers/preprocessing/tf_data_layer.py
# ...processing keras_core/src/layers/preprocessing/category_encoding.py
# ...processing keras_core/src/layers/preprocessing/center_crop.py
# ...processing keras_core/src/layers/reshaping/up_sampling2d.py
# ...processing keras_core/src/layers/reshaping/up_sampling3d.py
# ...processing keras_core/src/layers/reshaping/zero_padding2d.py
# ...processing keras_core/src/layers/reshaping/repeat_vector.py
# ...processing keras_core/src/layers/reshaping/cropping1d.py
# ...processing keras_core/src/layers/reshaping/zero_padding1d.py
# ...processing keras_core/src/layers/reshaping/up_sampling1d.py
# ...processing keras_core/src/layers/reshaping/__init__.py
# ...processing keras_core/src/layers/reshaping/permute.py
# ...processing keras_core/src/layers/reshaping/zero_padding3d.py
# ...processing keras_core/src/layers/reshaping/cropping3d.py
# ...processing keras_core/src/layers/reshaping/flatten.py
# ...processing keras_core/src/layers/reshaping/reshape.py
# ...processing keras_core/src/layers/reshaping/cropping2d.py
# ...processing keras_core/src/layers/regularization/dropout.py
# ...processing keras_core/src/layers/regularization/gaussian_noise.py
# ...processing keras_core/src/layers/regularization/spatial_dropout.py
# ...processing keras_core/src/layers/regularization/activity_regularization.py
# ...processing keras_core/src/layers/regularization/__init__.py
# ...processing keras_core/src/layers/regularization/gaussian_dropout.py
# ...processing keras_core/src/random/random.py
# ...processing keras_core/src/random/__init__.py
# ...processing keras_core/src/random/seed_generator.py
# ...processing keras_core/src/metrics/reduction_metrics.py
# ...processing keras_core/src/metrics/probabilistic_metrics.py
# ...processing keras_core/src/metrics/regression_metrics.py
# ...processing keras_core/src/metrics/iou_metrics.py
# ...processing keras_core/src/metrics/__init__.py
# ...processing keras_core/src/metrics/accuracy_metrics.py
# ...processing keras_core/src/metrics/metrics_utils.py
# ...processing keras_core/src/metrics/hinge_metrics.py
# ...processing keras_core/src/metrics/f_score_metrics.py
# ...processing keras_core/src/metrics/confusion_metrics.py
# ...processing keras_core/src/metrics/metric.py
# ...processing keras_core/src/datasets/fashion_mnist.py
# ...processing keras_core/src/datasets/cifar10.py
# ...processing keras_core/src/datasets/boston_housing.py
# ...processing keras_core/src/datasets/__init__.py
# ...processing keras_core/src/datasets/cifar100.py
# ...processing keras_core/src/datasets/reuters.py
# ...processing keras_core/src/datasets/imdb.py
# ...processing keras_core/src/datasets/california_housing.py
# ...processing keras_core/src/datasets/mnist.py
# ...processing keras_core/src/datasets/cifar.py
# ...processing keras_core/src/saving/object_registration.py
# ...processing keras_core/src/saving/__init__.py
# ...processing keras_core/src/saving/saving_api.py
# ...processing keras_core/src/saving/saving_lib.py
# ...processing keras_core/src/saving/serialization_lib.py
# ...processing keras_core/src/activations/activations.py
# ...processing keras_core/src/activations/__init__.py
# ...processing keras_core/src/utils/numerical_utils.py
# ...processing keras_core/src/utils/rng_utils.py
# ...processing keras_core/src/utils/file_utils.py
# ...processing keras_core/src/utils/python_utils.py
# ...processing keras_core/src/utils/progbar.py
# ...processing keras_core/src/utils/image_dataset_utils.py
# ...processing keras_core/src/utils/text_dataset_utils.py
# ...processing keras_core/src/utils/io_utils.py
# ...processing keras_core/src/utils/traceback_utils.py
# ...processing keras_core/src/utils/nest.py
# ...processing keras_core/src/utils/__init__.py
# ...processing keras_core/src/utils/dataset_utils.py
# ...processing keras_core/src/utils/model_visualization.py
# ...processing keras_core/src/utils/summary_utils.py
# ...processing keras_core/src/utils/backend_utils.py
# ...processing keras_core/src/utils/timeseries_dataset_utils.py
# ...processing keras_core/src/utils/sequence_utils.py
# ...processing keras_core/src/utils/audio_dataset_utils.py
# ...processing keras_core/src/utils/image_utils.py
# ...processing keras_core/src/utils/code_stats.py
# ...processing keras_core/src/utils/tracking.py
# ...processing keras_core/src/utils/dtype_utils.py
# ...processing keras_core/src/utils/argument_validation.py
# ...processing keras_core/src/utils/module_utils.py
# ...processing keras_core/src/utils/shape_utils.py
# ...processing keras_core/src/utils/tf_utils.py
# ...processing keras_core/src/utils/naming.py
# ...processing keras_core/src/callbacks/tensorboard.py
# ...processing keras_core/src/callbacks/terminate_on_nan.py
# ...processing keras_core/src/callbacks/callback_list.py
# ...processing keras_core/src/callbacks/history.py
# ...processing keras_core/src/callbacks/reduce_lr_on_plateau.py
# ...processing keras_core/src/callbacks/__init__.py
# ...processing keras_core/src/callbacks/remote_monitor.py
# ...processing keras_core/src/callbacks/callback.py
# ...processing keras_core/src/callbacks/model_checkpoint.py
# ...processing keras_core/src/callbacks/learning_rate_scheduler.py
# ...processing keras_core/src/callbacks/progbar_logger.py
# ...processing keras_core/src/callbacks/csv_logger.py
# ...processing keras_core/src/callbacks/lambda_callback.py
# ...processing keras_core/src/callbacks/early_stopping.py
# ...processing keras_core/src/models/sequential.py
# ...processing keras_core/src/models/variable_mapping.py
# ...processing keras_core/src/models/__init__.py
# ...processing keras_core/src/models/model.py
# ...processing keras_core/src/models/functional.py
# ...processing keras_core/src/models/cloning.py
# ...processing keras_core/src/backend/config.py
# ...processing keras_core/src/backend/__init__.py
# ...processing keras_core/src/backend/exports.py
# ...processing keras_core/src/backend/tensorflow/image.py
# ...processing keras_core/src/backend/tensorflow/math.py
# ...processing keras_core/src/backend/tensorflow/tensorboard.py
# ...processing keras_core/src/backend/tensorflow/random.py
# ...processing keras_core/src/backend/tensorflow/core.py
# ...processing keras_core/src/backend/tensorflow/optimizer.py
# ...processing keras_core/src/backend/tensorflow/rnn.py
# ...processing keras_core/src/backend/tensorflow/__init__.py
# ...processing keras_core/src/backend/tensorflow/layer.py
# ...processing keras_core/src/backend/tensorflow/numpy.py
# ...processing keras_core/src/backend/tensorflow/trainer.py
# ...processing keras_core/src/backend/tensorflow/nn.py
# ...processing keras_core/src/backend/torch/image.py
# ...processing keras_core/src/backend/torch/math.py
# ...processing keras_core/src/backend/torch/random.py
# ...processing keras_core/src/backend/torch/core.py
# ...processing keras_core/src/backend/torch/rnn.py
# ...processing keras_core/src/backend/torch/__init__.py
# ...processing keras_core/src/backend/torch/layer.py
# ...processing keras_core/src/backend/torch/numpy.py
# ...processing keras_core/src/backend/torch/trainer.py
# ...processing keras_core/src/backend/torch/nn.py
# ...processing keras_core/src/backend/torch/optimizers/torch_adadelta.py
# ...processing keras_core/src/backend/torch/optimizers/torch_nadam.py
# ...processing keras_core/src/backend/torch/optimizers/__init__.py
# ...processing keras_core/src/backend/torch/optimizers/torch_adamw.py
# ...processing keras_core/src/backend/torch/optimizers/torch_adamax.py
# ...processing keras_core/src/backend/torch/optimizers/torch_rmsprop.py
# ...processing keras_core/src/backend/torch/optimizers/torch_optimizer.py
# ...processing keras_core/src/backend/torch/optimizers/torch_adagrad.py
# ...processing keras_core/src/backend/torch/optimizers/torch_parallel_optimizer.py
# ...processing keras_core/src/backend/torch/optimizers/torch_adam.py
# ...processing keras_core/src/backend/torch/optimizers/torch_lion.py
# ...processing keras_core/src/backend/torch/optimizers/torch_sgd.py
# ...processing keras_core/src/backend/common/name_scope.py
# ...processing keras_core/src/backend/common/global_state.py
# ...processing keras_core/src/backend/common/__init__.py
# ...processing keras_core/src/backend/common/backend_utils.py
# ...processing keras_core/src/backend/common/variables.py
# ...processing keras_core/src/backend/common/stateless_scope.py
# ...processing keras_core/src/backend/common/keras_tensor.py
# ...processing keras_core/src/backend/numpy/image.py
# ...processing keras_core/src/backend/numpy/math.py
# ...processing keras_core/src/backend/numpy/random.py
# ...processing keras_core/src/backend/numpy/core.py
# ...processing keras_core/src/backend/numpy/rnn.py
# ...processing keras_core/src/backend/numpy/__init__.py
# ...processing keras_core/src/backend/numpy/layer.py
# ...processing keras_core/src/backend/numpy/numpy.py
# ...processing keras_core/src/backend/numpy/trainer.py
# ...processing keras_core/src/backend/numpy/nn.py
# ...processing keras_core/src/backend/jax/image.py
# ...processing keras_core/src/backend/jax/math.py
# ...processing keras_core/src/backend/jax/random.py
# ...processing keras_core/src/backend/jax/core.py
# ...processing keras_core/src/backend/jax/rnn.py
# ...processing keras_core/src/backend/jax/__init__.py
# ...processing keras_core/src/backend/jax/layer.py
# ...processing keras_core/src/backend/jax/numpy.py
# ...processing keras_core/src/backend/jax/distribution_lib.py
# ...processing keras_core/src/backend/jax/trainer.py
# ...processing keras_core/src/backend/jax/nn.py
# ...processing keras_core/src/losses/loss.py
# ...processing keras_core/src/losses/losses.py
# ...processing keras_core/src/losses/__init__.py
# ...processing keras_core/src/export/__init__.py
# ...processing keras_core/src/export/export_lib.py
# Generating files for package 'keras_core' from sources found in 'keras_core/src'.
# Using TensorFlow backend
# 2023-08-27 10:48:12.415245: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-27 10:48:13.327009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Compiling list of symbols to export.
# ...processing symbol 'Adam'
# ...processing symbol 'arccos'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'prod'
# ...processing symbol 'Embedding'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'random_bernoulli'
# ...processing symbol 'save_model'
# ...processing symbol 'while_loop'
# ...processing symbol 'InceptionV3'
# ...processing symbol 'random_normal'
# ...processing symbol 'Softmax'
# ...processing symbol 'random_normal_variable'
# ...processing symbol 'Tokenizer'
# ...processing symbol 'add'
# ...processing symbol 'DirectoryIterator'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'Ftrl'
# ...processing symbol 'random_uniform'
# ...processing symbol 'Rescaling'
# ...processing symbol 'Subtract'
# ...processing symbol 'deserialize'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'random_uniform_variable'
# ...processing symbol 'get'
# ...processing symbol 'stop_gradient'
# ...processing symbol 'arcsin'
# ...processing symbol 'reshape'
# ...processing symbol 'GlobalAveragePooling1D'
# ...processing symbol 'PyDataset'
# ...processing symbol 'relu'
# ...processing symbol 'Dot'
# ...processing symbol 'Bidirectional'
# ...processing symbol 'Dropout'
# ...processing symbol 'serialize'
# ...processing symbol 'repeat'
# ...processing symbol 'Activation'
# ...processing symbol 'arcsinh'
# ...processing symbol 'repeat_elements'
# ...processing symbol 'Conv2D'
# ...processing symbol 'fori_loop'
# ...processing symbol 'L2'
# ...processing symbol 'resize_images'
# ...processing symbol 'binary_accuracy'
# ...processing symbol 'MeanMetricWrapper'
# ...processing symbol 'resize_volumes'
# ...processing symbol 'EarlyStopping'
# ...processing symbol 'arctan'
# ...processing symbol 'MobileNetV3Small'
# ...processing symbol 'reverse'
# ...processing symbol 'OrthogonalInitializer'
# ...processing symbol 'deserialize'
# ...processing symbol 'MobileNetV3Large'
# ...processing symbol 'rnn'
# ...processing symbol 'random_rotation'
# ...processing symbol 'Normalization'
# ...processing symbol 'average'
# ...processing symbol 'OneHotIoU'
# ...processing symbol 'Metric'
# ...processing symbol 'PolynomialDecay'
# ...processing symbol 'unstack'
# ...processing symbol 'round'
# ...processing symbol 'TopKCategoricalAccuracy'
# ...processing symbol 'arctan2'
# ...processing symbol 'separable_conv2d'
# ...processing symbol 'set_value'
# ...processing symbol 'serialize'
# ...processing symbol 'Identity'
# ...processing symbol 'OrthogonalRegularizer'
# ...processing symbol 'shape'
# ...processing symbol 'Masking'
# ...processing symbol 'Accuracy'
# ...processing symbol 'shape'
# ...processing symbol 'arctanh'
# ...processing symbol 'sigmoid'
# ...processing symbol 'LambdaCallback'
# ...processing symbol 'RemoteMonitor'
# ...processing symbol 'cast'
# ...processing symbol 'sign'
# ...processing symbol 'MultiHeadAttention'
# ...processing symbol 'OneHotMeanIoU'
# ...processing symbol 'RandomBrightness'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'sin'
# ...processing symbol 'concatenate'
# ...processing symbol 'argmax'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'serialize'
# ...processing symbol 'softmax'
# ...processing symbol 'AveragePooling3D'
# ...processing symbol 'deserialize'
# ...processing symbol 'softplus'
# ...processing symbol 'Attention'
# ...processing symbol 'convert_to_tensor'
# ...processing symbol 'VGG19'
# ...processing symbol 'softsign'
# ...processing symbol 'random_shift'
# ...processing symbol 'unpack_x_y_sample_weight'
# ...processing symbol 'convert_to_numpy'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'sparse_categorical_crossentropy'
# ...processing symbol 'random_shear'
# ...processing symbol 'pack_x_y_sample_weight'
# ...processing symbol 'CustomObjectScope'
# ...processing symbol 'cond'
# ...processing symbol 'argmin'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'spatial_2d_padding'
# ...processing symbol 'random_zoom'
# ...processing symbol 'categorical_accuracy'
# ...processing symbol 'spatial_3d_padding'
# ...processing symbol 'apply_channel_shift'
# ...processing symbol 'get'
# ...processing symbol 'VGG16'
# ...processing symbol 'sqrt'
# ...processing symbol 'random_channel_shift'
# ...processing symbol 'SparseTopKCategoricalAccuracy'
# ...processing symbol 'SGD'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'square'
# ...processing symbol 'apply_brightness_shift'
# ...processing symbol 'sparse_categorical_accuracy'
# ...processing symbol 'argsort'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'squeeze'
# ...processing symbol 'random_brightness'
# ...processing symbol 'Ones'
# ...processing symbol 'AdditiveAttention'
# ...processing symbol 'stack'
# ...processing symbol 'RandomNormal'
# ...processing symbol 'std'
# ...processing symbol 'apply_affine_transform'
# ...processing symbol 'top_k_categorical_accuracy'
# ...processing symbol 'BinaryAccuracy'
# ...processing symbol 'segment_sum'
# ...processing symbol 'stop_gradient'
# ...processing symbol 'text_to_word_sequence'
# ...processing symbol 'array'
# ...processing symbol 'sum'
# ...processing symbol 'Model'
# ...processing symbol 'one_hot'
# ...processing symbol 'CallbackList'
# ...processing symbol 'InceptionResNetV2'
# ...processing symbol 'switch'
# ...processing symbol 'hashing_trick'
# ...processing symbol 'dot'
# ...processing symbol 'sparse_top_k_categorical_accuracy'
# ...processing symbol 'tanh'
# ...processing symbol 'tokenizer_from_json'
# ...processing symbol 'average'
# ...processing symbol 'serialize'
# ...processing symbol 'Identity'
# ...processing symbol 'temporal_padding'
# ...processing symbol 'Wrapper'
# ...processing symbol 'SimpleRNNCell'
# ...processing symbol 'Cropping1D'
# ...processing symbol 'tile'
# ...processing symbol 'AlphaDropout'
# ...processing symbol 'segment_max'
# ...processing symbol 'to_dense'
# ...processing symbol 'serialize'
# ...processing symbol 'Reshape'
# ...processing symbol 'transpose'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'bincount'
# ...processing symbol 'deserialize'
# ...processing symbol 'truncated_normal'
# ...processing symbol 'StackedRNNCells'
# ...processing symbol 'SensitivityAtSpecificity'
# ...processing symbol 'Constraint'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'update'
# ...processing symbol 'maximum'
# ...processing symbol 'ReLU'
# ...processing symbol 'top_k'
# ...processing symbol 'ResNet50V2'
# ...processing symbol 'update_add'
# ...processing symbol 'InverseTimeDecay'
# ...processing symbol 'LayerNormalization'
# ...processing symbol 'update_sub'
# ...processing symbol 'minimum'
# ...processing symbol 'deserialize'
# ...processing symbol 'clone_model'
# ...processing symbol 'StringLookup'
# ...processing symbol 'broadcast_to'
# ...processing symbol 'var'
# ...processing symbol 'get'
# ...processing symbol 'CSVLogger'
# ...processing symbol 'variable'
# ...processing symbol 'multiply'
# ...processing symbol 'in_top_k'
# ...processing symbol 'zeros'
# ...processing symbol 'enable_unsafe_deserialization'
# ...processing symbol 'VarianceScaling'
# ...processing symbol 'zeros_like'
# ...processing symbol 'subtract'
# ...processing symbol 'ceil'
# ...processing symbol 'ResNet50'
# ...processing symbol 'ResNet101'
# ...processing symbol 'EinsumDense'
# ...processing symbol 'ModelCheckpoint'
# ...processing symbol 'logsumexp'
# ...processing symbol 'ResNet152'
# ...processing symbol 'make_sampling_table'
# ...processing symbol 'clip'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'save_img'
# ...processing symbol 'SquaredHinge'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'ResNet101V2'
# ...processing symbol 'BatchNormalization'
# ...processing symbol 'qr'
# ...processing symbol 'get'
# ...processing symbol 'ResNet152V2'
# ...processing symbol 'RecallAtPrecision'
# ...processing symbol 'concatenate'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'serialize_keras_object'
# ...processing symbol 'HashedCrossing'
# ...processing symbol 'TrueNegatives'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'skipgrams'
# ...processing symbol 'ReduceLROnPlateau'
# ...processing symbol 'MobileNetV2'
# ...processing symbol 'deserialize_keras_object'
# ...processing symbol 'extract_sequences'
# ...processing symbol 'serialize_keras_object'
# ...processing symbol 'conjugate'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'Initializer'
# ...processing symbol 'fft'
# ...processing symbol 'conj'
# ...processing symbol 'CategoricalHinge'
# ...processing symbol 'Cropping3D'
# ...processing symbol 'copy'
# ...processing symbol 'deserialize_keras_object'
# ...processing symbol 'SparseCategoricalCrossentropy'
# ...processing symbol 'fft2'
# ...processing symbol 'GlorotUniform'
# ...processing symbol 'cos'
# ...processing symbol 'Zeros'
# ...processing symbol 'EfficientNetB0'
# ...processing symbol 'GlobalMaxPooling1D'
# ...processing symbol 'rfft'
# ...processing symbol 'EfficientNetB1'
# ...processing symbol 'cosh'
# ...processing symbol 'EfficientNetB2'
# ...processing symbol 'Flatten'
# ...processing symbol 'TimeDistributed'
# ...processing symbol 'KLDivergence'
# ...processing symbol 'EfficientNetB3'
# ...processing symbol 'load_img'
# ...processing symbol 'EfficientNetB4'
# ...processing symbol 'serialize'
# ...processing symbol 'TruePositives'
# ...processing symbol 'irfft'
# ...processing symbol 'count_nonzero'
# ...processing symbol 'EfficientNetB5'
# ...processing symbol 'MeanAbsolutePercentageError'
# ...processing symbol 'EfficientNetB6'
# ...processing symbol 'ExponentialDecay'
# ...processing symbol 'EfficientNetB7'
# ...processing symbol 'AUC'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'Poisson'
# ...processing symbol 'stft'
# ...processing symbol 'cross'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'GRU'
# ...processing symbol 'FBetaScore'
# ...processing symbol 'MeanSquaredLogarithmicError'
# ...processing symbol 'GlobalAveragePooling2D'
# ...processing symbol 'istft'
# ...processing symbol 'PiecewiseConstantDecay'
# ...processing symbol 'cumprod'
# ...processing symbol 'GlorotNormal'
# ...processing symbol 'F1Score'
# ...processing symbol 'BinaryCrossentropy'
# ...processing symbol 'rsqrt'
# ...processing symbol 'cumsum'
# ...processing symbol 'Mean'
# ...processing symbol 'diag'
# ...processing symbol 'relu'
# ...processing symbol 'hinge'
# ...processing symbol 'set_floatx'
# ...processing symbol 'squared_hinge'
# ...processing symbol 'BinaryFocalCrossentropy'
# ...processing symbol 'SimpleRNN'
# ...processing symbol 'serialize'
# ...processing symbol 'deserialize'
# ...processing symbol 'categorical_hinge'
# ...processing symbol 'set_dtype_policy'
# ...processing symbol 'mean_squared_error'
# ...processing symbol 'GlobalMaxPooling2D'
# ...processing symbol 'ZeroPadding2D'
# ...processing symbol 'Adafactor'
# ...processing symbol 'Input'
# ...processing symbol 'diagonal'
# ...processing symbol 'mean_absolute_error'
# ...processing symbol 'mean_absolute_percentage_error'
# ...processing symbol 'EfficientNetV2B0'
# ...processing symbol 'get'
# ...processing symbol 'mean_squared_logarithmic_error'
# ...processing symbol 'backend'
# ...processing symbol 'Permute'
# ...processing symbol 'TensorBoard'
# ...processing symbol 'Dense'
# ...processing symbol 'Callback'
# ...processing symbol 'EfficientNetV2B1'
# ...processing symbol 'Precision'
# ...processing symbol 'cosine_similarity'
# ...processing symbol 'Hashing'
# ...processing symbol 'digitize'
# ...processing symbol 'EfficientNetV2B2'
# ...processing symbol 'relu'
# ...processing symbol 'model_to_dot'
# ...processing symbol 'huber'
# ...processing symbol 'EfficientNetV2B3'
# ...processing symbol 'relu6'
# ...processing symbol 'log_cosh'
# ...processing symbol 'plot_model'
# ...processing symbol 'set_image_data_format'
# ...processing symbol 'EfficientNetV2S'
# ...processing symbol 'kl_divergence'
# ...processing symbol 'GlobalMaxPooling3D'
# ...processing symbol 'normalize'
# ...processing symbol 'dot'
# ...processing symbol 'EfficientNetV2M'
# ...processing symbol 'poisson'
# ...processing symbol 'epsilon'
# ...processing symbol 'UpSampling1D'
# ...processing symbol 'dtype_policy'
# ...processing symbol 'sigmoid'
# ...processing symbol 'EfficientNetV2L'
# ...processing symbol 'categorical_crossentropy'
# ...processing symbol 'to_categorical'
# ...processing symbol 'set_epsilon'
# ...processing symbol 'DepthwiseConv2D'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'RepeatVector'
# ...processing symbol 'serialize'
# ...processing symbol 'UnitNormalization'
# ...processing symbol 'categorical_focal_crossentropy'
# ...processing symbol 'History'
# ...processing symbol 'Recall'
# ...processing symbol 'Hinge'
# ...processing symbol 'serialize'
# ...processing symbol 'einsum'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'image_data_format'
# ...processing symbol 'sparse_categorical_crossentropy'
# ...processing symbol 'softplus'
# ...processing symbol 'binary_crossentropy'
# ...processing symbol 'RandomContrast'
# ...processing symbol 'Constant'
# ...processing symbol 'binary_focal_crossentropy'
# ...processing symbol 'UnitNorm'
# ...processing symbol 'MobileNet'
# ...processing symbol 'deserialize'
# ...processing symbol 'MaxPooling1D'
# ...processing symbol 'empty'
# ...processing symbol 'softsign'
# ...processing symbol 'get'
# ...processing symbol 'Huber'
# ...processing symbol 'SeedGenerator'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'equal'
# ...processing symbol 'silu'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'Xception'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'global_rng_state'
# ...processing symbol 'set_random_seed'
# ...processing symbol 'MinMaxNorm'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'exp'
# ...processing symbol 'log_sigmoid'
# ...processing symbol 'floatx'
# ...processing symbol 'AveragePooling2D'
# ...processing symbol 'Nadam'
# ...processing symbol 'AveragePooling1D'
# ...processing symbol 'MeanAbsolutePercentageError'
# ...processing symbol 'LogCosh'
# ...processing symbol 'pad_sequences'
# ...processing symbol 'moveaxis'
# ...processing symbol 'expand_dims'
# ...processing symbol 'leaky_relu'
# ...processing symbol 'CategoryEncoding'
# ...processing symbol 'LSTM'
# ...processing symbol 'text_dataset_from_directory'
# ...processing symbol 'Regularizer'
# ...processing symbol 'tri'
# ...processing symbol 'UpSampling2D'
# ...processing symbol 'MeanSquaredError'
# ...processing symbol 'nan_to_num'
# ...processing symbol 'expm1'
# ...processing symbol 'hard_sigmoid'
# ...processing symbol 'tril'
# ...processing symbol 'MeanSquaredLogarithmicError'
# ...processing symbol 'Hinge'
# ...processing symbol 'LecunNormal'
# ...processing symbol 'ExportArchive'
# ...processing symbol 'ndim'
# ...processing symbol 'timeseries_dataset_from_array'
# ...processing symbol 'clear_session'
# ...processing symbol 'NumpyArrayIterator'
# ...processing symbol 'elu'
# ...processing symbol 'flip'
# ...processing symbol 'L1L2'
# ...processing symbol 'nonzero'
# ...processing symbol 'triu'
# ...processing symbol 'SeparableConv2D'
# ...processing symbol 'RandomRotation'
# ...processing symbol 'ZeroPadding1D'
# ...processing symbol 'not_equal'
# ...processing symbol 'ConvNeXtTiny'
# ...processing symbol 'get_uid'
# ...processing symbol 'ProgbarLogger'
# ...processing symbol 'floor'
# ...processing symbol 'selu'
# ...processing symbol 'ConvNeXtSmall'
# ...processing symbol 'image_dataset_from_directory'
# ...processing symbol 'vdot'
# ...processing symbol 'ConvNeXtBase'
# ...processing symbol 'UpSampling3D'
# ...processing symbol 'ones_like'
# ...processing symbol 'ConvNeXtLarge'
# ...processing symbol 'array_to_img'
# ...processing symbol 'full'
# ...processing symbol 'L1'
# ...processing symbol 'gelu'
# ...processing symbol 'ConvNeXtXLarge'
# ...processing symbol 'vstack'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'ConvLSTM1D'
# ...processing symbol 'Optimizer'
# ...processing symbol 'zeros_like'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'img_to_array'
# ...processing symbol 'InputSpec'
# ...processing symbol 'RootMeanSquaredError'
# ...processing symbol 'full_like'
# ...processing symbol 'softmax'
# ...processing symbol 'where'
# ...processing symbol 'abs'
# ...processing symbol 'Concatenate'
# ...processing symbol 'SpatialDropout2D'
# ...processing symbol 'outer'
# ...processing symbol 'Loss'
# ...processing symbol 'LecunUniform'
# ...processing symbol 'get_item'
# ...processing symbol 'subtract'
# ...processing symbol 'is_keras_tensor'
# ...processing symbol 'log_softmax'
# ...processing symbol 'pad'
# ...processing symbol 'leaky_relu'
# ...processing symbol 'Adadelta'
# ...processing symbol 'greater'
# ...processing symbol 'GroupNormalization'
# ...processing symbol 'CosineSimilarity'
# ...processing symbol 'multiply'
# ...processing symbol 'SpatialDropout3D'
# ...processing symbol 'MeanAbsoluteError'
# ...processing symbol 'greater_equal'
# ...processing symbol 'max_pool'
# ...processing symbol 'divide'
# ...processing symbol 'prod'
# ...processing symbol 'SpectralNormalization'
# ...processing symbol 'audio_dataset_from_directory'
# ...processing symbol 'BinaryCrossentropy'
# ...processing symbol 'hstack'
# ...processing symbol 'average_pool'
# ...processing symbol 'true_divide'
# ...processing symbol 'ravel'
# ...processing symbol 'identity'
# ...processing symbol 'ActivityRegularization'
# ...processing symbol 'power'
# ...processing symbol 'all'
# ...processing symbol 'TextVectorization'
# ...processing symbol 'resize'
# ...processing symbol 'conv'
# ...processing symbol 'real'
# ...processing symbol 'HeNormal'
# ...processing symbol 'any'
# ...processing symbol 'RandomTranslation'
# ...processing symbol 'CategoricalCrossentropy'
# ...processing symbol 'TerminateOnNaN'
# ...processing symbol 'imag'
# ...processing symbol 'argmax'
# ...processing symbol 'TimeseriesGenerator'
# ...processing symbol 'negative'
# ...processing symbol 'argmin'
# ...processing symbol 'Reduction'
# ...processing symbol 'reciprocal'
# ...processing symbol 'arange'
# ...processing symbol 'depthwise_conv'
# ...processing symbol 'isclose'
# ...processing symbol 'batch_dot'
# ...processing symbol 'GaussianDropout'
# ...processing symbol 'square'
# ...processing symbol 'batch_flatten'
# ...processing symbol 'LeakyReLU'
# ...processing symbol 'repeat'
# ...processing symbol 'batch_get_value'
# ...processing symbol 'LogCoshError'
# ...processing symbol 'split_dataset'
# ...processing symbol 'HeUniform'
# ...processing symbol 'Lambda'
# ...processing symbol 'isfinite'
# ...processing symbol 'batch_set_value'
# ...processing symbol 'RandomZoom'
# ...processing symbol 'separable_conv'
# ...processing symbol 'sqrt'
# ...processing symbol 'batch_normalization'
# ...processing symbol 'load_model'
# ...processing symbol 'enable_interactive_logging'
# ...processing symbol 'bias_add'
# ...processing symbol 'LSTMCell'
# ...processing symbol 'isinf'
# ...processing symbol 'reshape'
# ...processing symbol 'binary_crossentropy'
# ...processing symbol 'get'
# ...processing symbol 'CategoricalCrossentropy'
# ...processing symbol 'squeeze'
# ...processing symbol 'binary_focal_crossentropy'
# ...processing symbol 'Conv1DTranspose'
# ...processing symbol 'KLDivergence'
# ...processing symbol 'conv_transpose'
# ...processing symbol 'cast'
# ...processing symbol 'CosineSimilarity'
# ...processing symbol 'Adamax'
# ...processing symbol 'MaxPooling3D'
# ...processing symbol 'R2Score'
# ...processing symbol 'isnan'
# ...processing symbol 'cast_to_floatx'
# ...processing symbol 'load_data'
# ...processing symbol 'roll'
# ...processing symbol 'categorical_crossentropy'
# ...processing symbol 'transpose'
# ...processing symbol 'categorical_focal_crossentropy'
# ...processing symbol 'Operation'
# ...processing symbol 'less'
# ...processing symbol 'one_hot'
# ...processing symbol 'clip'
# ...processing symbol 'Add'
# ...processing symbol 'RandomFlip'
# ...processing symbol 'CategoricalFocalCrossentropy'
# ...processing symbol 'concatenate'
# ...processing symbol 'load_data'
# ...processing symbol 'disable_interactive_logging'
# ...processing symbol 'round'
# ...processing symbol 'constant'
# ...processing symbol 'MeanSquaredError'
# ...processing symbol 'less_equal'
# ...processing symbol 'mean'
# ...processing symbol 'load_data'
# ...processing symbol 'Discretization'
# ...processing symbol 'binary_crossentropy'
# ...processing symbol 'linspace'
# ...processing symbol 'sign'
# ...processing symbol 'Conv3D'
# ...processing symbol 'ZeroPadding3D'
# ...processing symbol 'Average'
# ...processing symbol 'var'
# ...processing symbol 'conv1d'
# ...processing symbol 'SparseCategoricalCrossentropy'
# ...processing symbol 'categorical_crossentropy'
# ...processing symbol 'conv2d'
# ...processing symbol 'load_data'
# ...processing symbol 'sin'
# ...processing symbol 'conv2d_transpose'
# ...processing symbol 'MeanAbsoluteError'
# ...processing symbol 'log'
# ...processing symbol 'conv3d'
# ...processing symbol 'load_data'
# ...processing symbol 'sum'
# ...processing symbol 'cos'
# ...processing symbol 'SeparableConv1D'
# ...processing symbol 'sinh'
# ...processing symbol 'sparse_categorical_crossentropy'
# ...processing symbol 'count_params'
# ...processing symbol 'load_data'
# ...processing symbol 'enable_traceback_filtering'
# ...processing symbol 'log10'
# ...processing symbol 'ctc_batch_cost'
# ...processing symbol 'DepthwiseConv1D'
# ...processing symbol 'disable_traceback_filtering'
# ...processing symbol 'LearningRateScheduler'
# ...processing symbol 'Adagrad'
# ...processing symbol 'ctc_label_dense_to_sparse'
# ...processing symbol 'get_word_index'
# ...processing symbol 'SpecificityAtSensitivity'
# ...processing symbol 'is_interactive_logging_enabled'
# ...processing symbol 'is_traceback_filtering_enabled'
# ...processing symbol 'size'
# ...processing symbol 'zeros'
# ...processing symbol 'ctc_decode'
# ...processing symbol 'FeatureSpace'
# ...processing symbol 'RandomWidth'
# ...processing symbol 'log1p'
# ...processing symbol 'multi_hot'
# ...processing symbol 'cumsum'
# ...processing symbol 'Cropping2D'
# ...processing symbol 'GlobalAveragePooling3D'
# ...processing symbol 'RandomHeight'
# ...processing symbol 'load_data'
# ...processing symbol 'cumprod'
# ...processing symbol 'LearningRateSchedule'
# ...processing symbol 'StatelessScope'
# ...processing symbol 'ones'
# ...processing symbol 'sort'
# ...processing symbol 'depthwise_conv2d'
# ...processing symbol 'SquaredHinge'
# ...processing symbol 'load_data'
# ...processing symbol 'CosineDecay'
# ...processing symbol 'log2'
# ...processing symbol 'MaxNorm'
# ...processing symbol 'dot'
# ...processing symbol 'dropout'
# ...processing symbol 'get_word_index'
# ...processing symbol 'IoU'
# ...processing symbol 'eye'
# ...processing symbol 'dtype'
# ...processing symbol 'get_label_names'
# ...processing symbol 'Poisson'
# ...processing symbol 'logaddexp'
# ...processing symbol 'Sequential'
# ...processing symbol 'split'
# ...processing symbol 'elu'
# ...processing symbol 'ThresholdedReLU'
# ...processing symbol 'IntegerLookup'
# ...processing symbol 'equal'
# ...processing symbol 'floor_divide'
# ...processing symbol 'eval'
# ...processing symbol 'Progbar'
# ...processing symbol 'CategoricalHinge'
# ...processing symbol 'logical_and'
# ...processing symbol 'exp'
# ...processing symbol 'NonNeg'
# ...processing symbol 'stack'
# ...processing symbol 'expand_dims'
# ...processing symbol 'Resizing'
# ...processing symbol 'logical_xor'
# ...processing symbol 'eye'
# ...processing symbol 'ELU'
# ...processing symbol 'BinaryIoU'
# ...processing symbol 'logical_not'
# ...processing symbol 'flatten'
# ...processing symbol 'foldl'
# ...processing symbol 'Conv3DTranspose'
# ...processing symbol 'std'
# ...processing symbol 'foldr'
# ...processing symbol 'absolute'
# ...processing symbol 'logical_or'
# ...processing symbol 'gather'
# ...processing symbol 'deserialize'
# ...processing symbol 'preprocess_input'
# ...processing symbol 'get_value'
# ...processing symbol 'gradients'
# ...processing symbol 'abs'
# ...processing symbol 'logspace'
# ...processing symbol 'swapaxes'
# ...processing symbol 'greater'
# ...processing symbol 'normal'
# ...processing symbol 'MeanIoU'
# ...processing symbol 'CategoricalAccuracy'
# ...processing symbol 'relu6'
# ...processing symbol 'add'
# ...processing symbol 'decode_predictions'
# ...processing symbol 'greater_equal'
# ...processing symbol 'Conv2DTranspose'
# ...processing symbol 'softmax'
# ...processing symbol 'get_source_inputs'
# ...processing symbol 'hard_sigmoid'
# ...processing symbol 'categorical'
# ...processing symbol 'elu'
# ...processing symbol 'Layer'
# ...processing symbol 'CenterCrop'
# ...processing symbol 'PrecisionAtRecall'
# ...processing symbol 'FalsePositives'
# ...processing symbol 'in_top_k'
# ...processing symbol 'uniform'
# ...processing symbol 'selu'
# ...processing symbol 'Variable'
# ...processing symbol 'all'
# ...processing symbol 'matmul'
# ...processing symbol 'take'
# ...processing symbol 'int_shape'
# ...processing symbol 'randint'
# ...processing symbol 'softplus'
# ...processing symbol 'is_sparse'
# ...processing symbol 'truncated_normal'
# ...processing symbol 'softsign'
# ...processing symbol 'affine_transform'
# ...processing symbol 'l2_normalize'
# ...processing symbol 'dropout'
# ...processing symbol 'silu'
# ...processing symbol 'max'
# ...processing symbol 'less'
# ...processing symbol 'gelu'
# ...processing symbol 'ConvLSTM2D'
# ...processing symbol 'any'
# ...
# adding 'keras_core/src/saving/serialization_lib.py'
# adding 'keras_core/src/testing/__init__.py'
# adding 'keras_core/src/testing/test_case.py'
# adding 'keras_core/src/testing/test_utils.py'
# adding 'keras_core/src/trainers/__init__.py'
# adding 'keras_core/src/trainers/compile_utils.py'
# adding 'keras_core/src/trainers/epoch_iterator.py'
# adding 'keras_core/src/trainers/trainer.py'
# adding 'keras_core/src/trainers/data_adapters/__init__.py'
# adding 'keras_core/src/trainers/data_adapters/array_data_adapter.py'
# adding 'keras_core/src/trainers/data_adapters/data_adapter.py'
# adding 'keras_core/src/trainers/data_adapters/data_adapter_utils.py'
# adding 'keras_core/src/trainers/data_adapters/generator_data_adapter.py'
# adding 'keras_core/src/trainers/data_adapters/py_dataset_adapter.py'
# adding 'keras_core/src/trainers/data_adapters/tf_dataset_adapter.py'
# adding 'keras_core/src/trainers/data_adapters/torch_data_adapter.py'
# adding 'keras_core/src/utils/__init__.py'
# adding 'keras_core/src/utils/argument_validation.py'
# adding 'keras_core/src/utils/audio_dataset_utils.py'
# adding 'keras_core/src/utils/backend_utils.py'
# adding 'keras_core/src/utils/code_stats.py'
# adding 'keras_core/src/utils/dataset_utils.py'
# adding 'keras_core/src/utils/dtype_utils.py'
# adding 'keras_core/src/utils/file_utils.py'
# adding 'keras_core/src/utils/image_dataset_utils.py'
# adding 'keras_core/src/utils/image_utils.py'
# adding 'keras_core/src/utils/io_utils.py'
# adding 'keras_core/src/utils/model_visualization.py'
# adding 'keras_core/src/utils/module_utils.py'
# adding 'keras_core/src/utils/naming.py'
# adding 'keras_core/src/utils/nest.py'
# adding 'keras_core/src/utils/numerical_utils.py'
# adding 'keras_core/src/utils/progbar.py'
# adding 'keras_core/src/utils/python_utils.py'
# adding 'keras_core/src/utils/rng_utils.py'
# adding 'keras_core/src/utils/sequence_utils.py'
# adding 'keras_core/src/utils/shape_utils.py'
# adding 'keras_core/src/utils/summary_utils.py'
# adding 'keras_core/src/utils/text_dataset_utils.py'
# adding 'keras_core/src/utils/tf_utils.py'
# adding 'keras_core/src/utils/timeseries_dataset_utils.py'
# adding 'keras_core/src/utils/traceback_utils.py'
# adding 'keras_core/src/utils/tracking.py'
# adding 'keras_core/utils/__init__.py'
# adding 'keras_core/utils/legacy/__init__.py'
# adding 'keras_core-0.1.5.dist-info/METADATA'
# adding 'keras_core-0.1.5.dist-info/WHEEL'
# adding 'keras_core-0.1.5.dist-info/top_level.txt'
# adding 'keras_core-0.1.5.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built keras-core-0.1.5.tar.gz and keras_core-0.1.5-py3-none-any.whl
# Build successful. Wheel file available at /content/keras-core/dist/keras_core-0.1.5-py3-none-any.whl
# Installing wheel file: /content/keras-core/dist/keras_core-0.1.5-py3-none-any.whl
# Processing ./dist/keras_core-0.1.5-py3-none-any.whl
# Installing collected packages: keras-core
# Successfully installed keras-core-0.1.5
# Collecting git+https://github.com/soumik12345/wandb-addons
#   Cloning https://github.com/soumik12345/wandb-addons to /tmp/pip-req-build-drfxuiz9
#   Running command git clone --filter=blob:none --quiet https://github.com/soumik12345/wandb-addons /tmp/pip-req-build-drfxuiz9
#   Resolved https://github.com/soumik12345/wandb-addons to commit 9099f13c8cb2a5e189f4443072acb80a0a528840
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from wandb-addons==0.1.0) (8.1.7)
# Requirement already satisfied: nbformat<6.0.0,>=5.9.0 in /usr/local/lib/python3.10/dist-packages (from wandb-addons==0.1.0) (5.9.2)
# Collecting poetry<2.0.0,>=1.5.1 (from wandb-addons==0.1.0)
#   Downloading poetry-1.6.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.8/232.8 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from wandb-addons==0.1.0) (4.66.1)
# Collecting wandb<0.16.0,>=0.15.4 (from wandb-addons==0.1.0)
#   Downloading wandb-0.15.8-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0) (4.19.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0) (5.3.1)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0) (5.7.1)
# Requirement already satisfied: build<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (0.10.0)
# Requirement already satisfied: cachecontrol[filecache]<0.14.0,>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (0.13.1)
# Collecting cleo<3.0.0,>=2.0.0 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading cleo-2.0.1-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.3/77.3 kB 9.0 MB/s eta 0:00:00
# Collecting crashtest<0.5.0,>=0.4.1 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading crashtest-0.4.1-py3-none-any.whl (7.6 kB)
# Collecting dulwich<0.22.0,>=0.21.2 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading dulwich-0.21.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 kB 20.8 MB/s eta 0:00:00
# Collecting installer<0.8.0,>=0.7.0 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading installer-0.7.0-py3-none-any.whl (453 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 21.6 MB/s eta 0:00:00
# Collecting jsonschema>=2.6 (from nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0)
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 11.6 MB/s eta 0:00:00
# Collecting keyring<25.0.0,>=24.0.0 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading keyring-24.2.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: packaging>=20.4 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (23.1)
# Requirement already satisfied: pexpect<5.0.0,>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (4.8.0)
# Collecting pkginfo<2.0.0,>=1.9.4 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Requirement already satisfied: platformdirs<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (3.10.0)
# Collecting poetry-core==1.7.0 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Using cached poetry_core-1.7.0-py3-none-any.whl (426 kB)
# Collecting poetry-plugin-export<2.0.0,>=1.5.0 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading poetry_plugin_export-1.5.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyproject-hooks<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (1.0.0)
# Requirement already satisfied: requests<3.0,>=2.26 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (2.31.0)
# Collecting requests-toolbelt<2,>=0.9.1 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# Collecting shellingham<2.0,>=1.5 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading shellingham-1.5.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (2.0.1)
# Collecting tomlkit<1.0.0,>=0.11.4 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading tomlkit-0.12.1-py3-none-any.whl (37 kB)
# Collecting trove-classifiers>=2022.5.19 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading trove_classifiers-2023.8.7-py3-none-any.whl (13 kB)
# Collecting virtualenv<21.0.0,>=20.22.0 (from poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading virtualenv-20.24.3-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 34.0 MB/s eta 0:00:00
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading sentry_sdk-1.29.2-py2.py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 28.6 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0) (6.0.1)
# Collecting pathtools (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0) (3.20.3)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.14.0,>=0.13.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (1.0.5)
# Requirement already satisfied: filelock>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from cachecontrol[filecache]<0.14.0,>=0.13.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (3.12.2)
# Collecting rapidfuzz<3.0.0,>=2.2.0 (from cleo<3.0.0,>=2.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading rapidfuzz-2.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 48.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0) (1.16.0)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from dulwich<0.22.0,>=0.21.2->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (2.0.4)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0) (23.1.0)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema>=2.6->nbformat<6.0.0,>=5.9.0->wandb-addons==0.1.0)
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.3 MB/s eta 0:00:00
# Collecting jaraco.classes (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading jaraco.classes-3.3.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /usr/local/lib/python3.10/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (6.8.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect<5.0.0,>=4.7.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.26->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (2023.7.22)
# Collecting distlib<1,>=0.3.7 (from virtualenv<21.0.0,>=20.22.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0)
#   Downloading distlib-0.3.7-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 43.9 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb<0.16.0,>=0.15.4->wandb-addons==0.1.0)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (3.16.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from jaraco.classes->keyring<25.0.0,>=24.0.0->poetry<2.0.0,>=1.5.1->wandb-addons==0.1.0) (10.1.0)
# Building wheels for collected packages: wandb-addons, pathtools
#   Building wheel for wandb-addons (pyproject.toml) ... done
#   Created wheel for wandb-addons: filename=wandb_addons-0.1.0-py3-none-any.whl size=49157 sha256=6f279ef351a884ed4c739477121142b2fdef5d66ae6be975cc9a0654c935daf8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e6u947pq/wheels/0c/b4/b0/1c17696837762d57c4277bd554b1a2ab6d9a7a449f5e62ca2a
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=161c178c87c6f0d9c1f0403ac54444367d33b7a9a5fd002c46e242f825371d9c
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built wandb-addons pathtools
# Installing collected packages: trove-classifiers, pathtools, distlib, virtualenv, tomlkit, smmap, shellingham, setproctitle, sentry-sdk, rapidfuzz, pyrsistent, poetry-core, pkginfo, jaraco.classes, installer, dulwich, docker-pycreds, crashtest, requests-toolbelt, keyring, jsonschema, gitdb, cleo, GitPython, wandb, poetry-plugin-export, poetry, wandb-addons
#   Attempting uninstall: keyring
#     Found existing installation: keyring 23.5.0
#     Uninstalling keyring-23.5.0:
#       Successfully uninstalled keyring-23.5.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.0
#     Uninstalling jsonschema-4.19.0:
#       Successfully uninstalled jsonschema-4.19.0
# Successfully installed GitPython-3.1.32 cleo-2.0.1 crashtest-0.4.1 distlib-0.3.7 docker-pycreds-0.4.0 dulwich-0.21.5 gitdb-4.0.10 installer-0.7.0 jaraco.classes-3.3.0 jsonschema-4.17.3 keyring-24.2.0 pathtools-0.1.2 pkginfo-1.9.6 poetry-1.6.1 poetry-core-1.7.0 poetry-plugin-export-1.5.0 pyrsistent-0.19.3 rapidfuzz-2.15.1 requests-toolbelt-1.0.0 sentry-sdk-1.29.2 setproctitle-1.3.2 shellingham-1.5.3 smmap-5.0.0 tomlkit-0.12.1 trove-classifiers-2023.8.7 virtualenv-20.24.3 wandb-0.15.8 wandb-addons-0.1.0

# %%
import os

os.environ["KERAS_BACKEND"] = "torch"

import keras_core as keras
from keras_core import layers
from keras_core import ops

import numpy as np
import matplotlib.pyplot as plt

import wandb
from wandb_addons.keras import WandbMetricsLogger
from wandb_addons.keras import WandbModelCheckpoint
# Out:
# Using PyTorch backend.

# %%
num_classes = 100
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %%
wandb.init(project="kcd-kol")
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/content/wandb/run-20230827_105011-ab2b09vr</code>
# Syncing run <strong><a href='https://wandb.ai/19soumik-rakshit96/kcd-kol/runs/ab2b09vr' target="_blank">gallant-wood-7</a></strong> to <a href='https://wandb.ai/19soumik-rakshit96/kcd-kol' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/19soumik-rakshit96/kcd-kol' target="_blank">https://wandb.ai/19soumik-rakshit96/kcd-kol</a>
#  View run at <a href='https://wandb.ai/19soumik-rakshit96/kcd-kol/runs/ab2b09vr' target="_blank">https://wandb.ai/19soumik-rakshit96/kcd-kol/runs/ab2b09vr</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/19soumik-rakshit96/kcd-kol/runs/ab2b09vr?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 1
image_size = 72  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [
    2048,
    1024,
]  # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        input_shape = ops.shape(images)
        batch_size = input_shape[0]
        height = input_shape[1]
        width = input_shape[2]
        channels = input_shape[3]
        num_patches_h = height // self.patch_size
        num_patches_w = width // self.patch_size
        patches = keras.ops.image.extract_patches(images, size=self.patch_size)
        patches = ops.reshape(
            patches,
            (
                batch_size,
                num_patches_h * num_patches_w,
                self.patch_size * self.patch_size * channels,
            ),
        )
        return patches

    def get_config(self):
        config = super().get_config()
        config.update({"patch_size": self.patch_size})
        return config

# %%
plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = ops.image.resize(
    ops.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = ops.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(ops.convert_to_numpy(patch_img).astype("uint8"))
    plt.axis("off")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras_core/src/backend/torch/core.py:150: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   return torch.as_tensor(x, dtype=dtype, device=get_device())
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = ops.expand_dims(
            ops.arange(start=0, stop=self.num_patches, step=1), axis=0
        )
        projected_patches = self.projection(patch)
        encoded = projected_patches + self.position_embedding(positions)
        return encoded

    def get_config(self):
        config = super().get_config()
        config.update({"num_patches": self.num_patches})
        return config

# %%
def create_vit_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(
        representation, hidden_units=mlp_head_units, dropout_rate=0.5
    )
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(
                5, name="top-5-accuracy"
            ),
        ],
    )

    callbacks = [
        WandbMetricsLogger(log_freq="batch"),
        WandbModelCheckpoint("model.keras"),
    ]

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=callbacks,
    )


vit_classifier = create_vit_classifier()
run_experiment(vit_classifier)
wandb.finish()
# Out:
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 96s 534ms/step - accuracy: 0.0312 - loss: 4.9150 - top-5-accuracy: 0.1114 - val_accuracy: 0.1024 - val_loss: 3.9998 - val_top-5-accuracy: 0.2914
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>▁▃▃▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇████</td></tr><tr><td>batch/batch_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>batch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/loss</td><td>█▆▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>batch/top-5-accuracy</td><td>▁▂▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>epoch/accuracy</td><td>▁</td></tr><tr><td>epoch/epoch</td><td>▁</td></tr><tr><td>epoch/learning_rate</td><td>▁</td></tr><tr><td>epoch/loss</td><td>▁</td></tr><tr><td>epoch/top-5-accuracy</td><td>▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁</td></tr><tr><td>epoch/val_loss</td><td>▁</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>batch/accuracy</td><td>0.04791</td></tr><tr><td>batch/batch_step</td><td>175</td></tr><tr><td>batch/learning_rate</td><td>0.001</td></tr><tr><td>batch/loss</td><td>4.49284</td></tr><tr><td>batch/top-5-accuracy</td><td>0.15762</td></tr><tr><td>epoch/accuracy</td><td>0.04791</td></tr><tr><td>epoch/epoch</td><td>0</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>4.49284</td></tr><tr><td>epoch/top-5-accuracy</td><td>0.15762</td></tr><tr><td>epoch/val_accuracy</td><td>0.1024</td></tr><tr><td>epoch/val_loss</td><td>3.99979</td></tr><tr><td>epoch/val_top-5-accuracy</td><td>0.2914</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">gallant-wood-7</strong> at: <a href='https://wandb.ai/19soumik-rakshit96/kcd-kol/runs/ab2b09vr' target="_blank">https://wandb.ai/19soumik-rakshit96/kcd-kol/runs/ab2b09vr</a><br/> View job at <a href='https://wandb.ai/19soumik-rakshit96/kcd-kol/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjkzMDAzNjQ1/version_details/v2' target="_blank">https://wandb.ai/19soumik-rakshit96/kcd-kol/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjkzMDAzNjQ1/version_details/v2</a><br/>Synced 5 W&B file(s), 0 media file(s), 11 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20230827_105011-ab2b09vr/logs</code>
